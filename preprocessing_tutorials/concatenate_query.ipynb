# %% [markdown]
# Please copy this collab notebook in order to edit!
#
# Please add the names of the files you would like to concatenate in the closed brackets below (excluding the .h5ad extension)
#
# Your concatenated results will be saved as "archmap_results_concatenated.h5ad".
#
# Once you have finished editing, select Runtime -> Run all in the top left.

# %%
path = 'test_data'
file_names = ["delorey1","delorey2"] # please add the names of the files you would like to concatenate in the closed brackets (excluding the .h5ad extension)

# %%
# !pip install scanpy

# %%
import scanpy as sc

# %%
adata_full = sc.read(f"{path}/{file_names[0]}.h5ad")
for file_name in file_names[1:]:
  adata = sc.read(f"{path}/{file_name}.h5ad")
  adata_full = adata_full.concatenate(adata, batch_key='batch')

adata_full.write("archmap_results_concatenated.h5ad")
# Out:
# /tmp/ipykernel_3020099/2378510811.py:4: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_full = adata_full.concatenate(adata, batch_key='batch')
